# %%
import pandas as pd
from path import Path
from sklearn.preprocessing import StandardScaler
data_scaler = StandardScaler()

file_path = Path("chocolate.csv")
chocolate_df = pd.read_csv(file_path)
chocolate_df.head()
# Out:
#    Unnamed: 0   ref   company company_location  review_date  \
# 0           0  2454      5150            U.S.A         2019
# 1           1  2458      5150            U.S.A         2019
# 2           2  2454      5150            U.S.A         2019
# 3           3   797  A. Morin           France         2012
# 4           4   797  A. Morin           France         2012
#
#   country_of_bean_origin specific_bean_origin_or_bar_name  cocoa_percent  \
# 0             Madagascar           Bejofo Estate, batch 1           76.0
# 1     Dominican republic                  Zorzal, batch 1           76.0
# 2               Tanzania            Kokoa Kamili, batch 1           76.0
# 3                   Peru                             Peru           63.0
# 4                Bolivia                          Bolivia           70.0
#
#    rating  counts_of_ingredients  ...       cocoa_butter          vanilla  \
# 0    3.75                      3  ...  have_cocoa_butter  have_not_vanila
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df2 = chocolate_df.copy()
df2['cocoa_butter'] = le.fit_transform(df2['cocoa_butter'])
df2['vanilla'] = le.fit_transform(df2['vanilla'])
df2['lecithin'] = le.fit_transform(df2['lecithin'])
df2['salt'] = le.fit_transform(df2['salt'])
df2['sugar'] = le.fit_transform(df2['sugar'])
df2['sweetener_without_sugar'] = le.fit_transform(df2['sweetener_without_sugar'])
df2.head(50)
# Out:
#     Unnamed: 0   ref                        company company_location  \
# 0            0  2454                           5150            U.S.A
# 1            1  2458                           5150            U.S.A
# 2            2  2454                           5150            U.S.A
# 3            3   797                       A. Morin           France
# 4            4   797                       A. Morin           France
# 5            5  1015                       A. Morin           France
# 6            6  1019                       A. Morin           France
# 7            7  1011                       A. Morin           France
# 8            8  1019                       A. Morin           France
# 9            9  1011                       A. Morin           France
# 10          10  1015                       A. Morin           France
# 11          11  1019                       A. Morin           France
# 12          12  1011                       A. Morin           France
# ...
